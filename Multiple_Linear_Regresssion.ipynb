# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('Student_Performance.csv')

# %%
data
# Out:
#       Hours Studied  Previous Scores  ... Sample Question Papers Practiced  Performance Index
# 0                 7               99  ...                                1               91.0
# 1                 4               82  ...                                2               65.0
# 2                 8               51  ...                                2               45.0
# 3                 5               52  ...                                2               36.0
# 4                 7               75  ...                                5               66.0
# ...             ...              ...  ...                              ...                ...
# 9995              1               49  ...                                2               23.0
# 9996              7               64  ...                                5               58.0
# 9997              6               83  ...                                5               74.0
# ...

# %%
null_values = data.isnull().sum()
null_values
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
x = data[['Hours Studied', 'Previous Scores', 'Sleep Hours', 'Sample Question Papers Practiced']]
y = data['Performance Index']

# %%
plt.scatter(data['Previous Scores'],data['Performance Index'])
plt.xlabel('Previous Scores')
plt.ylabel('Performance Index')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
len(x_test), len(y_test)
# Out:
# (2000, 2000)

# %%
y_pred = model.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
plt.scatter(x_test['Previous Scores'], y_test)
plt.plot(x_test['Previous Scores'], y_pred, color='red')
plt.xlabel('Actual performance')
plt.ylabel('Predicted')
plt.show()

# %%
hours_studied = int(input('Hours Studied'))
previous_scores = int(input('Previous Scores'))
sleep_hours = int(input('Sleep Hours'))
sample_question_papers_practiced = int(input('Sample Question Papers Practiced'))
x_pred = model.predict([[hours_studied, previous_scores, sleep_hours, sample_question_papers_practiced]])
print(x_pred)
# Out:
# Hours Studied6
# Previous Scores89
# Sleep Hours8
# Sample Question Papers Practiced15
# [80.69391339]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
